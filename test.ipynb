# %%
# %load_ext autoreload
# %autoreload 2

import network
from ipywidgets import IntProgress
from IPython.display import display

# %%
p = network.Protein()
network.plot_random_walk(p.chain)

# %%
folds = 1000
f = IntProgress(min=0, max=folds)
display(f)
count = 0
while count <= folds:
    f.value += 1 
    p.random_fold_step()
    count += 1
network.plot_random_walk(p.chain)
# Out:
# IntProgress(value=0, max=1000)

# %%
print(p.chain)
# Out:
# [[12 21  0  2  0  0 19]
#  [13 21  1  0  0  4 15]
#  [13 22  1  0  3  0  5]
#  [13 23  0  0  3  4 18]
#  [12 23  0  2  0  4 10]
#  [11 23  1  2  0  0 12]
#  [11 24  0  2  3  0 10]
#  [12 24  0  2  0  4 11]
#  [13 24  1  0  0  4 17]
#  [13 25  0  0  3  4 13]
#  [12 25  0  2  0  4  6]
#  [11 25  1  2  0  0 18]
#  [11 26  0  2  3  0  9]
#  [12 26  1  0  0  4  6]
#  [12 27  0  2  3  0 15]
#  [13 27  1  0  0  4  4]
#  [13 28  1  0  3  0  6]
#  [13 29  0  0  3  4  6]
#  [12 29  0  2  3  0  2]
#  [12 28  1  0  0  4 12]
#  [11 28  0  2  0  4 11]
#  [10 28  0  2  0  4  4]
#  [ 9 28  0  2  0  4 13]
#  [ 8 28  0  2  0  4 13]
#  [ 7 28  0  2  3  0  4]
#  [ 7 27  1  0  0  4  0]
#  [ 6 27  0  2  0  4 15]
#  [ 5 27  1  2  0  0 15]
#  [ 5 28  0  0  3  4  0]
#  [ 4 28  0  2  0  0  1]]
